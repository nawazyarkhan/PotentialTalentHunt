# %%
# !pip install sklearn pandas matplotlib seaborn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'sklearn' when getting requirements to build wheel

# %%
### import libraries
# %pip install scikit-learn
import os
import sys
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from scikit-learn) (2.3.5)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.2-cp312-cp312-win_amd64.whl (8.7 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow_text
# import tensorflow_text as text  # Registers the ops.

# %%
# %pip install tensorflow tensorflow_hub
import tensorflow as tf
import tensorflow_hub as hub
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
preprocessor = hub.KerasLayer(
    "https://kaggle.com/models/tensorflow/bert/TensorFlow2/en-uncased-preprocess/3")
encoder_inputs = preprocessor(text_input)
encoder = hub.KerasLayer(
    "https://www.kaggle.com/models/tensorflow/bert/TensorFlow2/bert-en-uncased-l-10-h-128-a-2/2",
    trainable=True)
outputs = encoder(encoder_inputs)
pooled_output = outputs["pooled_output"]      # [batch_size, 128].
sequence_output = outputs["sequence_output"]  # [batch_size, seq_length, 128].
# Out:
# Requirement already satisfied: tensorflow in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (2.20.0)
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Collecting tf-keras>=2.14.1 (from tensorflow_hub)
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\my-pc\miniconda3\envs\tf_env_new\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 15.2 MB/s  0:00:00
# Installing collected packages: tf-keras, tensorflow_hub
#
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    -------------------- ------------------- 1/2 [tensorflow_hub]
#    ---------------------------------------- 2/2 [tensorflow_hub]
#
# Successfully installed tensorflow_hub-0.16.1 tf-keras-2.20.1
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\framework\ops.py:3105, in Graph.op_def_for_type(self, type)
#    3104 try:
# -> 3105   return self._op_def_cache[type]
#    3106 except KeyError:
#
# KeyError: 'CaseFoldUTF8'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 5
#       3 import tensorflow_hub as hub
#       4 text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
# ----> 5 preprocessor = hub.KerasLayer(
#       6     "https://kaggle.com/models/tensorflow/bert/TensorFlow2/en-uncased-preprocess/3")
#       7 encoder_inputs = preprocessor(text_input)
#       8 encoder = hub.KerasLayer(
#       9     "https://www.kaggle.com/models/tensorflow/bert/TensorFlow2/bert-en-uncased-l-10-h-128-a-2/2",
#      10     trainable=True)
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\keras_layer.py:165, in KerasLayer.__init__(self, handle, trainable, arguments, _sentinel, tags, signature, signature_outputs_as_dict, output_key, output_shape, load_options, **kwargs)
#     161   self._output_shape = data_structures.NoDependency(
#     162       _convert_nest_to_shapes(output_shape))
#     164 self._load_options = load_options
# --> 165 self._func = load_module(handle, tags, self._load_options)
#     166 self._is_hub_module_v1 = getattr(self._func, "_is_hub_module_v1", False)
#     168 # Update with the defaults when using legacy TF1 Hub format.
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\keras_layer.py:467, in load_module(handle, tags, load_options)
#     465     except ImportError:  # Expected before TF2.4.
#     466       set_load_options = load_options
# --> 467 return module_v2.load(handle, tags=tags, options=set_load_options)
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow_hub\module_v2.py:126, in load(handle, tags, options)
#     123   obj = tf.compat.v1.saved_model.load_v2(
#     124       module_path, tags=tags, options=options)
#     125 else:
# --> 126   obj = tf.compat.v1.saved_model.load_v2(module_path, tags=tags)
#     127 obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     128 return obj
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\saved_model\load.py:912, in load(export_dir, tags, options)
#     910 if isinstance(export_dir, os.PathLike):
#     911   export_dir = os.fspath(export_dir)
# --> 912 result = load_partial(export_dir, None, tags, options)["root"]
#     913 return result
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\saved_model\load.py:1042, in load_partial(export_dir, filters, tags, options)
#    1040 with ops.init_scope():
#    1041   try:
# -> 1042     loader = Loader(object_graph_proto, saved_model_proto, export_dir,
#    1043                     ckpt_options, options, filters)
#    1044   except errors.NotFoundError as err:
#    1045     raise FileNotFoundError(
#    1046         str(err) + "\n You may be trying to load on a different device "
#    1047         "from the computational device. Consider setting the "
#    1048         "`experimental_io_device` option in `tf.saved_model.LoadOptions` "
#    1049         "to the io_device such as '/job:localhost'.")
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\saved_model\load.py:161, in Loader.__init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     158 self._proto = object_graph_proto
#     159 self._export_dir = export_dir
#     160 self._concrete_functions = (
# --> 161     function_deserialization.load_function_def_library(
#     162         library=meta_graph.graph_def.library,
#     163         saved_object_graph=self._proto,
#     164         wrapper_function=_WrapperFunction))
#     165 # Store a set of all concrete functions that have been set up with
#     166 # captures.
#     167 self._restored_concrete_functions = set()
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\saved_model\function_deserialization.py:456, in load_function_def_library(library, saved_object_graph, load_shared_name_suffix, wrapper_function)
#     450 # There is no need to copy all functions into the function def graph. It
#     451 # leads to a O(n^2) increase of memory when importing functions and the
#     452 # extra function definitions are a no-op since they already imported as a
#     453 # function before and passed in explicitly (due to the topologic sort
#     454 # import).
#     455 with graph.as_default():
# --> 456   func_graph = function_def_lib.function_def_to_graph(
#     457       fdef,
#     458       structured_input_signature=structured_input_signature,
#     459       structured_outputs=structured_outputs)
#     460 # Restores gradients for function-call ops (not the same as ops that use
#     461 # custom gradients)
#     462 _restore_gradient_functions(func_graph, renamed_functions, loaded_gradients)
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\framework\function_def_to_graph.py:91, in function_def_to_graph(fdef, structured_input_signature, structured_outputs, input_shapes, propagate_device_spec, include_library_functions)
#      88       else:
#      89         input_shapes.append(input_shape)
# ---> 91 graph_def, nested_to_flat_tensor_name = function_def_to_graph_def(
#      92     fdef, input_shapes, include_library_functions=include_library_functions
#      93 )
#      95 with func_graph.as_default():
#      96   # Add all function nodes to the graph.
#      97   importer.import_graph_def_for_function(
#      98       graph_def, name="", propagate_device_spec=propagate_device_spec)
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\framework\function_def_to_graph.py:330, in function_def_to_graph_def(fdef, input_shapes, include_library_functions)
#     328       graph_def.library.gradient.extend([grad_def])
#     329 else:
# --> 330   op_def = default_graph.op_def_for_type(node_def.op)  # pylint: disable=protected-access
#     332 for attr in op_def.attr:
#     333   if attr.type == "func":
#
# File c:\Users\My-PC\miniconda3\envs\tf_env_new\Lib\site-packages\tensorflow\python\framework\ops.py:3108, in Graph.op_def_for_type(self, type)
#    3105   return self._op_def_cache[type]
#    3106 except KeyError:
#    3107   self._op_def_cache[type] = op_def_pb2.OpDef.FromString(
# -> 3108       self._op_def_for_type(type)
#    3109   )
#    3110   return self._op_def_cache[type]
#
# RuntimeError: Op type not registered 'CaseFoldUTF8' in binary running on NKHAN-DELL-PC. Make sure the Op and Kernel are registered in the binary running in this process. Note that if you are loading a saved graph which used ops from tf.contrib (e.g. `tf.contrib.resampler`), accessing should be done before importing the graph, as contrib ops are lazily registered when the module is first accessed.
